# %%
import pickle
from evaluation import get_metric
import h5py
import numpy as np

# Get Answer
h5f_valid = h5py.File('../Hanseul/Container/train_cpl', 'r')
answer = h5f_valid['labels_id'][:].astype(np.int64)
h5f_valid.close()

# Get Reco result
with open("./recs/Graph_rec_cpl_4_1_depth_2.pickle", 'rb') as f:
    recs = pickle.load(f)
    
answer_dict = {}
for i, ans in enumerate(answer):
    answer_dict[i] = ans

# %%
metric = get_metric(recs, answer_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 metric = get_metric(recs, answer_dict)
#
# File D:\Programming\Lecture_Project\AI506\Team_Project\cuisine-prediction\Chanho\evaluation.py:64, in get_metric(recs, answer, mode, n)
#      62 answer_ = [item for query, item in sorted(list(answer.items()))]
#      63 metric = {}
# ---> 64 metric['macro'] = get_f1_macro(top_rec, answer_)
#      65 metric['micro'] = get_f1_micro(top_rec, answer_)
#      66 metric['accuracy'] = get_acc(top_rec, answer_)
#
# File D:\Programming\Lecture_Project\AI506\Team_Project\cuisine-prediction\Chanho\evaluation.py:8, in get_f1_macro(recs, answer)
#       7 def get_f1_macro(recs, answer):
# ----> 8     return f1_score(answer, recs, average='macro')
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1123, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     992 def f1_score(
#     993     y_true,
#     994     y_pred,
#    (...)
#    1000     zero_division="warn",
#    1001 ):
#    1002     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1003
#    1004     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1121     modified with ``zero_division``.
#    1122     """
# -> 1123     return fbeta_score(
#    1124         y_true,
#    1125         y_pred,
#    1126         beta=1,
#    1127         labels=labels,
#    1128         pos_label=pos_label,
#    1129         average=average,
#    1130         sample_weight=sample_weight,
#    1131         zero_division=zero_division,
#    1132     )
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1261, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1135 def fbeta_score(
#    1136     y_true,
#    1137     y_pred,
#    (...)
#    1144     zero_division="warn",
#    1145 ):
#    1146     """Compute the F-beta score.
#    1147
#    1148     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1258     array([0.71..., 0.        , 0.        ])
#    1259     """
# -> 1261     _, _, f, _ = precision_recall_fscore_support(
#    1262         y_true,
#    1263         y_pred,
#    1264         beta=beta,
#    1265         labels=labels,
#    1266         pos_label=pos_label,
#    1267         average=average,
#    1268         warn_for=("f-score",),
#    1269         sample_weight=sample_weight,
#    1270         zero_division=zero_division,
#    1271     )
#    1272     return f
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1544, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542 if beta < 0:
#    1543     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1546 # Calculate tp_sum, pred_sum, true_sum ###
#    1547 samplewise = average == "samples"
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1348, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1345 if average not in average_options and average != "binary":
#    1346     raise ValueError("average has to be one of " + str(average_options))
# -> 1348 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349 # Convert to Python primitive type to avoid NumPy type / Python str
#    1350 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1351 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     330 uniques = np.unique(lengths)
#     331 if len(uniques) > 1:
# --> 332     raise ValueError(
#     333         "Found input variables with inconsistent numbers of samples: %r"
#     334         % [int(l) for l in lengths]
#     335     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [253419, 7848]

# %%
metric
# Out:
# {'macro': 0.001089542780199017,
#  'micro': 0.07135575942915393,
#  'accuracy': 0.07135575942915393,
#  'map': 0.12983931807517468,
#  'recall': 0.29281345565749234,
#  'recall_rank': 4.110095735422107}

# %%
# Get Reco result
from tqdm import tqdm
acc_lst = []
for i in tqdm(range(10)):
    with open("./train_recs/Graph_rec_cpl_1_4_depth_{}.pickle".format(i), 'rb') as f:
        recs = pickle.load(f)
    metric = get_metric(recs, answer_dict)
    acc_lst.append(metric['accuracy'])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:58<00:00,  5.88s/it]

# %%
import matplotlib.pyplot as plt
ratio_lst = [w1/w2 for w1, w2 in [(1,4)]]
depth_lst = list(range(1, 11))

plt.figure(figsize=(8,5))
for ratio in ratio_lst:
    plt.plot(depth_lst, acc_lst, 'o-', label=str(ratio))
plt.title("Recall@10 of Graph Model Completion Task")
plt.xlabel('Traverse depth')
plt.ylabel('Recall@10')
plt.xticks(depth_lst)
plt.legend()
#plt.savefig('./data_analysis/graph_cpl_recall10.png', dpi=100)
plt.show()
